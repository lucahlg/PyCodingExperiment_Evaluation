# %%
import os
import subprocess
import codecs

def convert_to_utf8(file_path):
    """
    Convert the given file to UTF-8 encoding.
    """
    try:
        with codecs.open(file_path, 'r', encoding='latin1') as file:
            content = file.read()
        with codecs.open(file_path, 'w', encoding='utf-8') as file:
            file.write(content)
    except Exception as e:
        print(f"Error converting {file_path} to UTF-8: {e}")

def get_pylint_score(file_path):
    """
    Run pylint on the given Python file and return its score and full output.
    """
    try:
        # Convert the file to UTF-8 encoding
        convert_to_utf8(file_path)
        
        result = subprocess.run(
            ['pylint', file_path, '--score=y', '--exit-zero'],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )
        # Extract the output and attempt to parse the score
        full_output = result.stdout
        score = "N/A"
        for line in full_output.splitlines():
            if "Your code has been rated at" in line:
                score = line.split("at")[1].split("/")[0].strip()  # Extract the score
                break
        return score, full_output
    except Exception as e:
        return f"Error: {e}", ""

def rate_python_files():
    """
    Iterate through the current working directory and its subdirectories,
    run pylint on all .py files, and print the scores and outputs.
    """
    current_folder = os.getcwd()
    results = []
    for subdir, _, files in os.walk(current_folder):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(subdir, file)
                score, full_output = get_pylint_score(file_path)
                results.append((file_path, score, full_output))
    return results

if __name__ == "__main__":
    print("\nScanning Python files in the current directory and rating them with pylint...\n")
    
    ratings = rate_python_files()
    
    print("Pylint Ratings:\n")
    for file_path, score, full_output in ratings:
        print(f"File: {file_path}")
        print(f"Score: {score}")
        print("Full Output:")
        print(full_output)
        print("-" * 80)
# Out:
# Scanning Python files in the current directory and rating them with pylint...
#
# Pylint Ratings:
#
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\01\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 01\ipynb.py:88:0: C0305: Trailing newlines (trailing-newlines)
# 01\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 01\ipynb.py:4:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 01\ipynb.py:28:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 01\ipynb.py:42:0: W0404: Reimport 'StandardScaler' (imported line 28) (reimported)
# 01\ipynb.py:42:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 01\ipynb.py:54:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 01\ipynb.py:71:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 01\ipynb.py:72:0: C0413: Import "import seaborn as sns" should be placed at the top of the module (wrong-import-position)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.43/10 (previous run: 6.92/10, +0.51)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\02\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 02\ipynb.py:85:0: C0301: Line too long (164/100) (line-too-long)
# 02\ipynb.py:88:0: C0305: Trailing newlines (trailing-newlines)
# 02\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 02\ipynb.py:4:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 02\ipynb.py:28:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 02\ipynb.py:42:0: W0404: Reimport 'StandardScaler' (imported line 28) (reimported)
# 02\ipynb.py:42:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 02\ipynb.py:54:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 02\ipynb.py:71:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 02\ipynb.py:72:0: C0413: Import "import seaborn as sns" should be placed at the top of the module (wrong-import-position)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.14/10 (previous run: 7.43/10, -0.29)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\03\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 03\ipynb.py:88:0: C0305: Trailing newlines (trailing-newlines)
# 03\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 03\ipynb.py:4:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 03\ipynb.py:28:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 03\ipynb.py:42:0: W0404: Reimport 'StandardScaler' (imported line 28) (reimported)
# 03\ipynb.py:42:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 03\ipynb.py:54:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 03\ipynb.py:71:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 03\ipynb.py:72:0: C0413: Import "import seaborn as sns" should be placed at the top of the module (wrong-import-position)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.43/10 (previous run: 7.14/10, +0.29)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\04\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 04\ipynb.py:86:0: C0305: Trailing newlines (trailing-newlines)
# 04\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 04\ipynb.py:4:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 04\ipynb.py:28:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 04\ipynb.py:42:0: W0404: Reimport 'StandardScaler' (imported line 28) (reimported)
# 04\ipynb.py:42:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 04\ipynb.py:54:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 04\ipynb.py:69:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 04\ipynb.py:70:0: C0413: Import "import seaborn as sns" should be placed at the top of the module (wrong-import-position)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.43/10 (previous run: 7.43/10, +0.00)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\05\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 05\ipynb.py:88:0: C0305: Trailing newlines (trailing-newlines)
# 05\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 05\ipynb.py:4:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 05\ipynb.py:28:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 05\ipynb.py:42:0: W0404: Reimport 'StandardScaler' (imported line 28) (reimported)
# 05\ipynb.py:42:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 05\ipynb.py:54:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 05\ipynb.py:71:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 05\ipynb.py:72:0: C0413: Import "import seaborn as sns" should be placed at the top of the module (wrong-import-position)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.43/10 (previous run: 7.43/10, +0.00)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\06\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 06\ipynb.py:88:0: C0305: Trailing newlines (trailing-newlines)
# 06\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 06\ipynb.py:7:0: C0103: Constant name "url" doesn't conform to UPPER_CASE naming style (invalid-name)
# 06\ipynb.py:8:11: W3101: Missing timeout argument for method 'requests.get' can cause your program to hang indefinitely (missing-timeout)
# 06\ipynb.py:11:0: C0103: Constant name "zip_file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 06\ipynb.py:34:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 06\ipynb.py:44:0: W0404: Reimport 'StandardScaler' (imported line 34) (reimported)
# 06\ipynb.py:44:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 06\ipynb.py:52:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 06\ipynb.py:62:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 06\ipynb.py:63:0: C0413: Import "import seaborn as sns" should be placed at the top of the module (wrong-import-position)
# 06\ipynb.py:87:0: W0104: Statement seems to have no effect (pointless-statement)
# 06\ipynb.py:2:0: C0411: standard import "zipfile" should be placed before third party import "pandas" (wrong-import-order)
# 06\ipynb.py:4:0: C0411: standard import "os" should be placed before third party imports "pandas", "requests" (wrong-import-order)
# 06\ipynb.py:4:0: W0611: Unused import os (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.94/10 (previous run: 7.43/10, -0.49)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\07\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 07\ipynb.py:32:0: C0301: Line too long (110/100) (line-too-long)
# 07\ipynb.py:60:0: C0301: Line too long (110/100) (line-too-long)
# 07\ipynb.py:99:0: C0305: Trailing newlines (trailing-newlines)
# 07\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 07\ipynb.py:7:0: C0103: Constant name "url" doesn't conform to UPPER_CASE naming style (invalid-name)
# 07\ipynb.py:8:11: W3101: Missing timeout argument for method 'requests.get' can cause your program to hang indefinitely (missing-timeout)
# 07\ipynb.py:11:0: C0103: Constant name "zip_file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 07\ipynb.py:36:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 07\ipynb.py:53:0: W0404: Reimport 'pandas' (imported line 1) (reimported)
# 07\ipynb.py:53:0: C0413: Import "import pandas as pd" should be placed at the top of the module (wrong-import-position)
# 07\ipynb.py:54:0: W0404: Reimport 'StandardScaler' (imported line 36) (reimported)
# 07\ipynb.py:54:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 07\ipynb.py:69:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 07\ipynb.py:77:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 07\ipynb.py:98:0: W0104: Statement seems to have no effect (pointless-statement)
# 07\ipynb.py:2:0: C0411: standard import "zipfile" should be placed before third party import "pandas" (wrong-import-order)
# 07\ipynb.py:4:0: C0411: standard import "os" should be placed before third party imports "pandas", "requests" (wrong-import-order)
# 07\ipynb.py:53:0: C0412: Imports from package pandas are not grouped (ungrouped-imports)
# 07\ipynb.py:54:0: C0412: Imports from package sklearn are not grouped (ungrouped-imports)
# 07\ipynb.py:4:0: W0611: Unused import os (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.30/10 (previous run: 6.94/10, -0.64)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\08\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 08\ipynb.py:81:0: C0305: Trailing newlines (trailing-newlines)
# 08\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 08\ipynb.py:4:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 08\ipynb.py:19:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 08\ipynb.py:31:0: W0404: Reimport 'StandardScaler' (imported line 19) (reimported)
# 08\ipynb.py:31:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 08\ipynb.py:41:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 08\ipynb.py:51:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 08\ipynb.py:52:0: C0413: Import "import seaborn as sns" should be placed at the top of the module (wrong-import-position)
# 08\ipynb.py:74:4: C0103: Constant name "description" doesn't conform to UPPER_CASE naming style (invalid-name)
# 08\ipynb.py:80:0: W0104: Statement seems to have no effect (pointless-statement)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.50/10 (previous run: 6.30/10, +1.20)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\09\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 09\ipynb.py:21:0: C0301: Line too long (110/100) (line-too-long)
# 09\ipynb.py:84:0: C0305: Trailing newlines (trailing-newlines)
# 09\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 09\ipynb.py:4:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 09\ipynb.py:26:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 09\ipynb.py:38:0: W0404: Reimport 'StandardScaler' (imported line 26) (reimported)
# 09\ipynb.py:38:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 09\ipynb.py:48:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 09\ipynb.py:57:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 09\ipynb.py:58:0: C0413: Import "import numpy as np" should be placed at the top of the module (wrong-import-position)
# 09\ipynb.py:83:0: W0104: Statement seems to have no effect (pointless-statement)
# 09\ipynb.py:58:0: W0611: Unused numpy imported as np (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.07/10 (previous run: 7.50/10, -0.43)
#
#
# --------------------------------------------------------------------------------
# File: c:\Users\LucaH\Repositories\PyCodingExperiment_Evaluation\02_data_science\results\T3\10\ipynb.py
# Score: ed
# Full Output:
# ************* Module ipynb
# 10\ipynb.py:21:0: C0301: Line too long (110/100) (line-too-long)
# 10\ipynb.py:61:0: C0301: Line too long (110/100) (line-too-long)
# 10\ipynb.py:113:0: C0303: Trailing whitespace (trailing-whitespace)
# 10\ipynb.py:118:0: C0303: Trailing whitespace (trailing-whitespace)
# 10\ipynb.py:123:0: C0303: Trailing whitespace (trailing-whitespace)
# 10\ipynb.py:128:0: C0303: Trailing whitespace (trailing-whitespace)
# 10\ipynb.py:133:0: C0303: Trailing whitespace (trailing-whitespace)
# 10\ipynb.py:138:0: C0303: Trailing whitespace (trailing-whitespace)
# 10\ipynb.py:142:0: C0305: Trailing newlines (trailing-newlines)
# 10\ipynb.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# 10\ipynb.py:4:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 10\ipynb.py:26:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 10\ipynb.py:46:0: W0404: Reimport 'pandas' (imported line 1) (reimported)
# 10\ipynb.py:46:0: C0413: Import "import pandas as pd" should be placed at the top of the module (wrong-import-position)
# 10\ipynb.py:47:0: W0404: Reimport 'StandardScaler' (imported line 26) (reimported)
# 10\ipynb.py:47:0: C0413: Import "from sklearn.preprocessing import StandardScaler" should be placed at the top of the module (wrong-import-position)
# 10\ipynb.py:50:0: C0103: Constant name "file_path" doesn't conform to UPPER_CASE naming style (invalid-name)
# 10\ipynb.py:71:0: C0413: Import "from sklearn.cluster import KMeans" should be placed at the top of the module (wrong-import-position)
# 10\ipynb.py:80:0: C0413: Import "import matplotlib.pyplot as plt" should be placed at the top of the module (wrong-import-position)
# 10\ipynb.py:81:0: C0413: Import "import numpy as np" should be placed at the top of the module (wrong-import-position)
# 10\ipynb.py:103:0: W0104: Statement seems to have no effect (pointless-statement)
# 10\ipynb.py:108:4: C0103: Constant name "description" doesn't conform to UPPER_CASE naming style (invalid-name)
# 10\ipynb.py:141:0: W0104: Statement seems to have no effect (pointless-statement)
# 10\ipynb.py:46:0: C0412: Imports from package pandas are not grouped (ungrouped-imports)
# 10\ipynb.py:47:0: C0412: Imports from package sklearn are not grouped (ungrouped-imports)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.58/10 (previous run: 7.07/10, -0.50)
#
#
# --------------------------------------------------------------------------------
